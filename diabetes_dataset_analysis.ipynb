# %%
import pandas as pd
df=pd.read_csv("diabetes_data.csv")
df.shape
df.columns
df.dtypes
# Out:
# user_id                   int64
# date                     object
# weight                  float64
# height                  float64
# blood_glucose           float64
# physical_activity       float64
# diet                      int64
# medication_adherence      int64
# stress_level              int64
# sleep_hours             float64
# hydration_level           int64
# bmi                     float64
# risk_score              float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   user_id               1000 non-null   int64
#  1   date                  1000 non-null   object
#  2   weight                1000 non-null   float64
#  3   height                1000 non-null   float64
#  4   blood_glucose         1000 non-null   float64
#  5   physical_activity     1000 non-null   float64
#  6   diet                  1000 non-null   int64
#  7   medication_adherence  1000 non-null   int64
#  8   stress_level          1000 non-null   int64
#  9   sleep_hours           1000 non-null   float64
#  10  hydration_level       1000 non-null   int64
#  11  bmi                   1000 non-null   float64
#  12  risk_score            1000 non-null   float64
# dtypes: float64(7), int64(5), object(1)
# memory usage: 101.7+ KB

# %%
df.describe()
# Out:
#            user_id       weight       height  blood_glucose  \
# count  1000.000000  1000.000000  1000.000000    1000.000000
# mean    500.500000    70.361797   170.795375     140.818899
# std     288.819436    14.467165     9.742934      38.064177
# min       1.000000    40.000000   150.000000      70.000000
# 25%     250.750000    60.286145   163.937583     114.080015
# 50%     500.500000    70.379509   170.630771     139.989969
# 75%     750.250000    79.719158   177.288822     166.436613
# max    1000.000000   120.000000   200.000000     297.049508
#
#        physical_activity         diet  medication_adherence  stress_level  \
# count        1000.000000  1000.000000            1000.00000   1000.000000
# mean           30.294497     0.604000               0.69300      0.950000
# std            19.305165     0.489309               0.46148      0.833183
# min             0.000000     0.000000               0.00000      0.000000
# ...

# %%
df.isnull().sum()
# Out:
# user_id                 0
# date                    0
# weight                  0
# height                  0
# blood_glucose           0
# physical_activity       0
# diet                    0
# medication_adherence    0
# stress_level            0
# sleep_hours             0
# hydration_level         0
# bmi                     0
# risk_score              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   user_id               1000 non-null   int64
#  1   date                  1000 non-null   object
#  2   weight                1000 non-null   float64
#  3   height                1000 non-null   float64
#  4   blood_glucose         1000 non-null   float64
#  5   physical_activity     1000 non-null   float64
#  6   diet                  1000 non-null   int64
#  7   medication_adherence  1000 non-null   int64
#  8   stress_level          1000 non-null   int64
#  9   sleep_hours           1000 non-null   float64
#  10  hydration_level       1000 non-null   int64
#  11  bmi                   1000 non-null   float64
#  12  risk_score            1000 non-null   float64
# dtypes: float64(7), int64(5), object(1)
# memory usage: 101.7+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# user_id                 1000
# date                    1000
# weight                   984
# height                   982
# blood_glucose            964
# physical_activity        925
# diet                       2
# medication_adherence       2
# stress_level               3
# sleep_hours              927
# hydration_level            2
# bmi                      257
# risk_score               899
# dtype: int64

# %%
df['age'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1197/4073793540.py in <cell line: 0>()
# ----> 1 df['age'].unique()
#
# ...

# %%
df['outcome'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'outcome'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1197/1581142076.py in <cell line: 0>()
# ----> 1 df['outcome'].unique()
#
# ...

# %%
df['blood_glucose'].unique()
# Out:
# array([112.992869  , 134.21925317, 108.30320316, 127.68153881,
#         70.        , 148.53174829, 140.04821901, 107.31645476,
#        166.36982674, 177.50280551,  75.69760543, 109.49100886,
#        109.23430601, 102.40387596, 173.17899368, 132.24695445,
#        129.41940635, 165.41672121,  90.42966421, 142.39730521,
#        151.09507752, 194.42634383,  87.64718404, 147.35398179,
#        212.02044726, 189.55785412, 148.38637661, 120.33455257,
#        172.28490387, 101.05815201, 159.05431077, 160.21880637,
#        182.4083963 , 250.38640156, 155.69663869, 119.64145497,
#        138.97702751, 112.21147476, 123.62870248, 119.03646408,
#        146.09419488, 107.1032027 , 184.84122669, 140.0082826 ,
#        139.62798715, 126.88421134, 146.20762735, 173.00393059,
#        105.31479137, 113.67534044, 127.85095885,  86.16516306,
#        107.22968561, 120.95116506, 174.97556723, 150.50245316,
#        147.74359645, 174.03591849, 134.50512846, 155.618594  ,
# ...

# %%
df['bmi'].unique()
# Out:
# array([22.9, 21.1, 27.4, 34.7, 21.2, 22. , 29.3, 26.2, 19.3, 28.8, 18.8,
#        21.3, 20.2, 15.5, 12.6, 20.8, 20.5, 20.3, 16.1, 30. , 24.7, 24.6,
#        13.3, 17.6, 23.6, 18.2, 25.8, 19.7, 25.7, 21.8, 41.6, 23.1, 17.4,
#        30.2, 15. , 29.4, 16.8, 16.9, 22.4, 23.2, 26.5, 20.9, 22.8, 18.5,
#        36.1, 12.9, 27.9, 19.6, 26.6, 31.6, 31.5, 19.9, 19.8, 24.4, 30.6,
#        29.9, 16.2, 29.7, 35.8, 27.6, 20. , 30.5, 23.8, 37.8, 12.4, 23.9,
#        24.1, 27.2, 33.1, 17.1, 19.2, 20.6, 25.2, 22.1, 27.5, 24.9, 18.9,
#        20.4, 25.5, 32.8, 15.1, 28.3, 17.8, 31.7, 28.6, 14.6, 23.5, 22.2,
#        34.9, 18.3, 29.5, 25. , 17. , 19.5, 22.7, 40.9, 18.4, 23.3, 15.6,
#        23.4, 25.3, 28.9, 16.4, 26.3, 24.8, 26.1, 28.2, 20.7, 22.5, 28.5,
#        33.4, 22.3, 21.4, 36.8, 28.7, 35.9, 24.5, 26. , 31.9, 18. , 28.1,
#        32.1, 43.8, 26.9, 32.4, 25.1, 30.1, 18.6, 21.6, 33.8, 15.7, 29.1,
#        34.1, 32.7, 31.8, 21.9, 24. , 19.4, 41.9, 14. , 30.3, 19. , 21.7,
# ...

# %%
df.isin([0]).sum()
# Out:
# user_id                   0
# date                      0
# weight                    0
# height                    0
# blood_glucose             0
# physical_activity        76
# diet                    396
# medication_adherence    307
# stress_level            373
# sleep_hours               0
# hydration_level         290
# bmi                       0
# risk_score                2
# dtype: int64

# %%
(df['blood_glucose']==0).sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Selecting and filtering data**
#
# ---

# %%
df[['blood_glucose','bmi']]
# Out:
#      blood_glucose   bmi
# 0       112.992869  22.9
# 1       134.219253  21.1
# 2       108.303203  27.4
# 3       127.681539  34.7
# 4        70.000000  21.2
# ..             ...   ...
# 995     143.099221  20.1
# 996     150.310102  33.7
# 997      90.329577  30.6
# 998     153.367057  21.7
# 999     133.789638  29.7
#
# [1000 rows x 2 columns]

# %%
df[df['weight']>50]
# Out:
#      user_id        date     weight      height  blood_glucose  \
# 0          1  2021-01-01  77.450712  183.993554     112.992869
# 1          2  2021-01-02  67.926035  179.246337     134.219253
# 2          3  2021-01-03  79.715328  170.596304     108.303203
# 3          4  2021-01-04  92.845448  163.530632     127.681539
# 4          5  2021-01-05  66.487699  176.982233      70.000000
# ..       ...         ...        ...         ...            ...
# 995      996  2023-12-26  65.783496  180.701502     143.099221
# 996      997  2023-12-27  96.965298  169.734787     150.310102
# 997      998  2023-12-28  79.612643  161.181253      90.329577
# 998      999  2023-12-29  61.432315  168.369330     153.367057
# 999     1000  2023-12-31  78.588742  162.550974     133.789638
#
#      physical_activity  diet  medication_adherence  stress_level  sleep_hours  \
# 0             0.000000     1                     0             1     6.342317
# ...

# %%
df[(df['weight']>50 & df['risk_score']==1)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     361         #  (xint or xbool) and (yint or bool)
# --> 362         result = op(x, y)
#     363     except TypeError:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/roperator.py in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#      55
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
# ...

# %%
#Access rows by index(iloc)
df.iloc[0:5]
# Out:
#    user_id        date     weight      height  blood_glucose  \
# 0        1  2021-01-01  77.450712  183.993554     112.992869
# 1        2  2021-01-02  67.926035  179.246337     134.219253
# 2        3  2021-01-03  79.715328  170.596304     108.303203
# 3        4  2021-01-04  92.845448  163.530632     127.681539
# 4        5  2021-01-05  66.487699  176.982233      70.000000
#
#    physical_activity  diet  medication_adherence  stress_level  sleep_hours  \
# 0           0.000000     1                     0             1     6.342317
# 1          12.792300     0                     1             2    10.658122
# 2          21.727889     1                     1             0     5.997832
# 3          67.753753     1                     0             1     7.958814
# 4          41.131062     1                     1             0     6.774707
#
#    hydration_level   bmi  risk_score
# 0                1  22.9   38.000000
# 1                1  21.1   39.162310
# ...

# %%
#sorting and grouping
df.sort_values(by='weight',ascending=False).head()
# Out:
#      user_id        date      weight      height  blood_glucose  \
# 209      210  2021-08-17  120.000000  187.495767     139.971656
# 478      479  2022-06-08  116.183212  161.125078      86.455768
# 179      180  2021-07-16  110.802537  158.964107     140.271994
# 755      756  2023-04-07  109.485731  183.736585     121.933621
# 654      655  2022-12-18  108.600397  173.384838     113.686618
#
#      physical_activity  diet  medication_adherence  stress_level  sleep_hours  \
# 209          39.024506     1                     1             2     7.138736
# 478          53.071807     0                     1             1     8.551293
# 179          40.312562     1                     0             0     9.223397
# 755           0.000000     0                     0             1     9.245784
# 654          32.987270     0                     1             0     8.282121
#
#      hydration_level   bmi  risk_score
# 209                0  34.1   45.243873
# ...

# %%
df.sort_values(by='weight',ascending=False).tail()
# Out:
#      user_id        date  weight      height  blood_glucose  \
# 382      383  2022-02-23    40.0  191.573082     153.751515
# 262      263  2021-10-14    40.0  175.387560     189.431288
# 236      237  2021-09-16    40.0  186.777008     140.570923
# 74        75  2021-03-23    40.0  179.962668     115.293924
# 991      992  2023-12-22    40.0  177.542913     164.084733
#
#      physical_activity  diet  medication_adherence  stress_level  sleep_hours  \
# 382          34.251481     1                     1             2     6.002547
# 262          11.907713     1                     0             0     4.238332
# 236          50.148879     1                     1             0     8.229824
# 74           15.339340     1                     1             1     7.925875
# 991          20.574725     1                     1             1     4.999174
#
#      hydration_level   bmi  risk_score
# 382                0  10.9   31.437130
# 262                1  13.0   46.392538
# ...

# %% [markdown]
# **GROUP BY AND AGGREGATE**

# %%
df.groupby('weight').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %%
df['bmi'].mean()
# Out:
# np.float64(24.3855)

# %%
df['blood_glucose'].mean()
# Out:
# np.float64(140.818898915992)

# %%
df['blood_glucose'].median()
# Out:
# 139.98996940683102

# %%
df['weight'].mode()
# Out:
# 0    40.0
# Name: weight, dtype: float64

# %%
df['weight'].value_counts()
# Out:
# weight
# 40.000000    17
# 69.638124     1
# 72.971271     1
# 67.834594     1
# 61.395070     1
#              ..
# 57.617542     1
# 65.179212     1
# 76.193972     1
# 61.544132     1
# 54.909739     1
# Name: count, Length: 984, dtype: int64

# %%
df['weight'].std()
# Out:
# 14.467164994484909

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1197/1134722465.py in <cell line: 0>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...
